# %% [markdown]
# ## Prepare the workspace

# %%
# Check torch version and CUDA status if GPU is enabled.
import torch
print(torch.__version__)
#print(torch.cuda.is_available()) # Should return True when GPU is enabled.

#####################
# Set device
#####################

device = (
    torch.accelerator.current_accelerator().type
    if torch.accelerator.is_available()
    else "cpu"
)

# Legacy PyTorch
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Device set to: {device}")
# Out:
# 2.9.1
# Device set to: mps

# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

import torch
from torch import nn
from torch import optim
from torchvision import datasets, transforms, models

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
#####################
# Load the data
#####################

data_dir = 'data/flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# DONE: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
}

# DONE: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}

# DONE: Using the image datasets and the trainforms, define the dataloaders
dataloaders = {
    'train': torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True),
    'valid': torch.utils.data.DataLoader(image_datasets['valid'], batch_size=64, shuffle=False),
    'test': torch.utils.data.DataLoader(image_datasets['test'], batch_size=64, shuffle=False)
}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# DONE: Build and train your network

#####################
# Load the model
#####################

weights = models.VGG16_Weights.DEFAULT
model = models.vgg16(weights=weights)
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
##########################################
# Prepare the model for transfer learning
##########################################

# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False

# Create a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
classifier = nn.Sequential(
    # First hidden layer: 25088 down to 4096
    nn.Linear(25088, 4096),
    nn.ReLU(),
    nn.Dropout(p=0.2),

    # Second hidden layer: 4096 down to 512
    nn.Linear(4096, 512),
    nn.ReLU(),
    nn.Dropout(p=0.2),

    nn.Linear(512, 102),
    nn.LogSoftmax(dim=1)
)

# Replace the model's classifier with the new classifier' and check the new model's architecture.
model.classifier = classifier
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=4096, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=102, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
criterion = nn.NLLLoss()

optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)

model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=4096, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=102, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
#####################
# Train the model
#####################

epochs = 5
steps = 0
running_loss = 0
print_every = 5

for epoch in range(epochs):
    for images, labels in dataloaders['train']:

        # Move input and label tensors to the default device
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        logps = model.forward(images)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        if steps % print_every == 0:
            test_loss = 0
            accuracy = 0

            model.eval()

            with torch.no_grad():
                for images, labels in dataloaders['valid']:
                    images, labels = images.to(device), labels.to(device)
                    logps = model.forward(images)
                    batch_loss = criterion(logps, labels)

                    test_loss += batch_loss.item()

                    # calculate accuracy
                    ps = torch.exp(logps)
                    top_p, top_class = ps.topk(1, dim=1)
                    equality = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equality.type(torch.FloatTensor)).item()

                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"Test loss: {test_loss/len(dataloaders['valid']):.3f}.. "
                      f"Test accuracy: {accuracy/len(dataloaders['valid']):.3f}")

                running_loss = 0
                model.train()
# Out:
# Epoch 1/5.. Train loss: 0.927.. Test loss: 28.215.. Test accuracy: 0.028
# Epoch 1/5.. Train loss: 6.114.. Test loss: 22.983.. Test accuracy: 0.025
# Epoch 1/5.. Train loss: 4.329.. Test loss: 11.104.. Test accuracy: 0.036
# Epoch 1/5.. Train loss: 2.318.. Test loss: 6.179.. Test accuracy: 0.014
# Epoch 1/5.. Train loss: 1.206.. Test loss: 4.979.. Test accuracy: 0.014
# Epoch 1/5.. Train loss: 1.010.. Test loss: 4.699.. Test accuracy: 0.023
# Epoch 1/5.. Train loss: 0.986.. Test loss: 4.600.. Test accuracy: 0.014
# Epoch 1/5.. Train loss: 0.931.. Test loss: 4.558.. Test accuracy: 0.023
# Epoch 1/5.. Train loss: 0.913.. Test loss: 4.507.. Test accuracy: 0.038
# Epoch 1/5.. Train loss: 0.922.. Test loss: 4.460.. Test accuracy: 0.053
# Epoch 1/5.. Train loss: 0.924.. Test loss: 4.412.. Test accuracy: 0.076
# Epoch 1/5.. Train loss: 0.907.. Test loss: 4.353.. Test accuracy: 0.096
# Epoch 1/5.. Train loss: 0.888.. Test loss: 4.289.. Test accuracy: 0.112
# Epoch 1/5.. Train loss: 0.863.. Test loss: 4.222.. Test accuracy: 0.106
# Epoch 1/5.. Train loss: 0.900.. Test loss: 4.166.. Test accuracy: 0.108
# Epoch 1/5.. Train loss: 0.863.. Test loss: 4.132.. Test accuracy: 0.106
# Epoch 1/5.. Train loss: 0.863.. Test loss: 4.118.. Test accuracy: 0.113
# Epoch 1/5.. Train loss: 0.838.. Test loss: 4.072.. Test accuracy: 0.107
# Epoch 1/5.. Train loss: 0.861.. Test loss: 3.972.. Test accuracy: 0.132
# Epoch 1/5.. Train loss: 0.874.. Test loss: 3.909.. Test accuracy: 0.170
# Epoch 1/5.. Train loss: 0.810.. Test loss: 3.818.. Test accuracy: 0.189
# Epoch 1/5.. Train loss: 0.781.. Test loss: 3.735.. Test accuracy: 0.189
# Epoch 1/5.. Train loss: 0.769.. Test loss: 3.734.. Test accuracy: 0.181
# Epoch 1/5.. Train loss: 0.789.. Test loss: 3.692.. Test accuracy: 0.186
# Epoch 1/5.. Train loss: 0.757.. Test loss: 3.559.. Test accuracy: 0.200
# Epoch 1/5.. Train loss: 0.791.. Test loss: 3.523.. Test accuracy: 0.199
# Epoch 1/5.. Train loss: 0.794.. Test loss: 3.541.. Test accuracy: 0.188
# Epoch 1/5.. Train loss: 0.684.. Test loss: 3.507.. Test accuracy: 0.197
# Epoch 1/5.. Train loss: 0.728.. Test loss: 3.392.. Test accuracy: 0.219
# Epoch 1/5.. Train loss: 0.673.. Test loss: 3.322.. Test accuracy: 0.225
# Epoch 1/5.. Train loss: 0.671.. Test loss: 3.236.. Test accuracy: 0.237
# Epoch 1/5.. Train loss: 0.727.. Test loss: 3.164.. Test accuracy: 0.250
# Epoch 1/5.. Train loss: 0.622.. Test loss: 3.100.. Test accuracy: 0.262
# Epoch 1/5.. Train loss: 0.744.. Test loss: 3.018.. Test accuracy: 0.288
# Epoch 1/5.. Train loss: 0.744.. Test loss: 2.976.. Test accuracy: 0.283
# Epoch 1/5.. Train loss: 0.689.. Test loss: 2.920.. Test accuracy: 0.302
# Epoch 1/5.. Train loss: 0.735.. Test loss: 2.838.. Test accuracy: 0.331
# Epoch 1/5.. Train loss: 0.675.. Test loss: 2.793.. Test accuracy: 0.353
# Epoch 1/5.. Train loss: 0.661.. Test loss: 2.811.. Test accuracy: 0.327
# Epoch 1/5.. Train loss: 0.719.. Test loss: 2.802.. Test accuracy: 0.325
# Epoch 1/5.. Train loss: 0.692.. Test loss: 2.732.. Test accuracy: 0.331
# Epoch 1/5.. Train loss: 0.659.. Test loss: 2.598.. Test accuracy: 0.369
# Epoch 1/5.. Train loss: 0.600.. Test loss: 2.535.. Test accuracy: 0.392
# Epoch 1/5.. Train loss: 0.668.. Test loss: 2.512.. Test accuracy: 0.386
# Epoch 1/5.. Train loss: 0.594.. Test loss: 2.525.. Test accuracy: 0.390
# Epoch 1/5.. Train loss: 0.652.. Test loss: 2.518.. Test accuracy: 0.388
# Epoch 1/5.. Train loss: 0.610.. Test loss: 2.544.. Test accuracy: 0.371
# Epoch 1/5.. Train loss: 0.627.. Test loss: 2.574.. Test accuracy: 0.359
# Epoch 1/5.. Train loss: 0.685.. Test loss: 2.515.. Test accuracy: 0.367
# Epoch 1/5.. Train loss: 0.631.. Test loss: 2.495.. Test accuracy: 0.387
# Epoch 1/5.. Train loss: 0.571.. Test loss: 2.489.. Test accuracy: 0.375
# Epoch 1/5.. Train loss: 0.613.. Test loss: 2.467.. Test accuracy: 0.379
# Epoch 1/5.. Train loss: 0.591.. Test loss: 2.406.. Test accuracy: 0.397
# Epoch 1/5.. Train loss: 0.629.. Test loss: 2.343.. Test accuracy: 0.414
# Epoch 1/5.. Train loss: 0.642.. Test loss: 2.308.. Test accuracy: 0.431
# Epoch 1/5.. Train loss: 0.545.. Test loss: 2.301.. Test accuracy: 0.435
# Epoch 1/5.. Train loss: 0.530.. Test loss: 2.262.. Test accuracy: 0.442
# Epoch 1/5.. Train loss: 0.536.. Test loss: 2.232.. Test accuracy: 0.456
# Epoch 1/5.. Train loss: 0.529.. Test loss: 2.241.. Test accuracy: 0.425
# Epoch 1/5.. Train loss: 0.542.. Test loss: 2.268.. Test accuracy: 0.400
# Epoch 1/5.. Train loss: 0.567.. Test loss: 2.251.. Test accuracy: 0.411
# Epoch 1/5.. Train loss: 0.608.. Test loss: 2.212.. Test accuracy: 0.425
# Epoch 1/5.. Train loss: 0.456.. Test loss: 2.206.. Test accuracy: 0.438
# Epoch 1/5.. Train loss: 0.600.. Test loss: 2.175.. Test accuracy: 0.457
# Epoch 1/5.. Train loss: 0.606.. Test loss: 2.222.. Test accuracy: 0.449
# Epoch 1/5.. Train loss: 0.653.. Test loss: 2.215.. Test accuracy: 0.442
# Epoch 1/5.. Train loss: 0.485.. Test loss: 2.244.. Test accuracy: 0.437
# Epoch 1/5.. Train loss: 0.612.. Test loss: 2.229.. Test accuracy: 0.426
# Epoch 1/5.. Train loss: 0.572.. Test loss: 2.197.. Test accuracy: 0.413
# Epoch 1/5.. Train loss: 0.569.. Test loss: 2.158.. Test accuracy: 0.439
# Epoch 1/5.. Train loss: 0.476.. Test loss: 2.106.. Test accuracy: 0.448
# Epoch 1/5.. Train loss: 0.489.. Test loss: 2.068.. Test accuracy: 0.458
# Epoch 1/5.. Train loss: 0.609.. Test loss: 2.053.. Test accuracy: 0.470
# Epoch 1/5.. Train loss: 0.612.. Test loss: 2.011.. Test accuracy: 0.474
# Epoch 1/5.. Train loss: 0.629.. Test loss: 1.975.. Test accuracy: 0.471
# Epoch 1/5.. Train loss: 0.564.. Test loss: 1.955.. Test accuracy: 0.475
# Epoch 1/5.. Train loss: 0.558.. Test loss: 1.936.. Test accuracy: 0.483
# Epoch 1/5.. Train loss: 0.512.. Test loss: 1.913.. Test accuracy: 0.495
# Epoch 1/5.. Train loss: 0.583.. Test loss: 1.940.. Test accuracy: 0.482
# Epoch 1/5.. Train loss: 0.474.. Test loss: 1.980.. Test accuracy: 0.475
# Epoch 1/5.. Train loss: 0.481.. Test loss: 1.966.. Test accuracy: 0.477
# Epoch 1/5.. Train loss: 0.554.. Test loss: 1.918.. Test accuracy: 0.500
# Epoch 1/5.. Train loss: 0.545.. Test loss: 1.846.. Test accuracy: 0.521
# Epoch 1/5.. Train loss: 0.486.. Test loss: 1.802.. Test accuracy: 0.513
# Epoch 1/5.. Train loss: 0.553.. Test loss: 1.780.. Test accuracy: 0.532
# Epoch 1/5.. Train loss: 0.491.. Test loss: 1.767.. Test accuracy: 0.536
# Epoch 1/5.. Train loss: 0.428.. Test loss: 1.745.. Test accuracy: 0.541
# Epoch 1/5.. Train loss: 0.577.. Test loss: 1.724.. Test accuracy: 0.551
# Epoch 1/5.. Train loss: 0.469.. Test loss: 1.741.. Test accuracy: 0.565
# Epoch 1/5.. Train loss: 0.411.. Test loss: 1.786.. Test accuracy: 0.545
# Epoch 1/5.. Train loss: 0.533.. Test loss: 1.800.. Test accuracy: 0.535
# Epoch 1/5.. Train loss: 0.506.. Test loss: 1.723.. Test accuracy: 0.548
# Epoch 1/5.. Train loss: 0.534.. Test loss: 1.697.. Test accuracy: 0.555
# Epoch 1/5.. Train loss: 0.475.. Test loss: 1.716.. Test accuracy: 0.549
# Epoch 1/5.. Train loss: 0.391.. Test loss: 1.762.. Test accuracy: 0.528
# Epoch 1/5.. Train loss: 0.515.. Test loss: 1.796.. Test accuracy: 0.520
# Epoch 1/5.. Train loss: 0.514.. Test loss: 1.831.. Test accuracy: 0.504
# Epoch 1/5.. Train loss: 0.428.. Test loss: 1.813.. Test accuracy: 0.509
# Epoch 1/5.. Train loss: 0.539.. Test loss: 1.755.. Test accuracy: 0.524
# Epoch 1/5.. Train loss: 0.562.. Test loss: 1.679.. Test accuracy: 0.540
# Epoch 1/5.. Train loss: 0.409.. Test loss: 1.641.. Test accuracy: 0.560
# Epoch 1/5.. Train loss: 0.464.. Test loss: 1.644.. Test accuracy: 0.560
# Epoch 1/5.. Train loss: 0.470.. Test loss: 1.654.. Test accuracy: 0.576
# Epoch 2/5.. Train loss: 0.501.. Test loss: 1.645.. Test accuracy: 0.574
# Epoch 2/5.. Train loss: 0.463.. Test loss: 1.613.. Test accuracy: 0.574
# Epoch 2/5.. Train loss: 0.460.. Test loss: 1.577.. Test accuracy: 0.584
# Epoch 2/5.. Train loss: 0.536.. Test loss: 1.574.. Test accuracy: 0.587
# Epoch 2/5.. Train loss: 0.376.. Test loss: 1.555.. Test accuracy: 0.569
# Epoch 2/5.. Train loss: 0.416.. Test loss: 1.531.. Test accuracy: 0.574
# Epoch 2/5.. Train loss: 0.426.. Test loss: 1.527.. Test accuracy: 0.591
# Epoch 2/5.. Train loss: 0.530.. Test loss: 1.536.. Test accuracy: 0.579
# Epoch 2/5.. Train loss: 0.387.. Test loss: 1.559.. Test accuracy: 0.580
# Epoch 2/5.. Train loss: 0.525.. Test loss: 1.563.. Test accuracy: 0.562
# Epoch 2/5.. Train loss: 0.483.. Test loss: 1.553.. Test accuracy: 0.584
# Epoch 2/5.. Train loss: 0.444.. Test loss: 1.542.. Test accuracy: 0.584
# Epoch 2/5.. Train loss: 0.453.. Test loss: 1.556.. Test accuracy: 0.576
# Epoch 2/5.. Train loss: 0.458.. Test loss: 1.583.. Test accuracy: 0.565
# Epoch 2/5.. Train loss: 0.585.. Test loss: 1.595.. Test accuracy: 0.564
# Epoch 2/5.. Train loss: 0.488.. Test loss: 1.630.. Test accuracy: 0.550
# Epoch 2/5.. Train loss: 0.456.. Test loss: 1.632.. Test accuracy: 0.552
# Epoch 2/5.. Train loss: 0.433.. Test loss: 1.603.. Test accuracy: 0.557
# Epoch 2/5.. Train loss: 0.517.. Test loss: 1.561.. Test accuracy: 0.571
# Epoch 2/5.. Train loss: 0.443.. Test loss: 1.552.. Test accuracy: 0.574
# Epoch 2/5.. Train loss: 0.444.. Test loss: 1.571.. Test accuracy: 0.566
# Epoch 2/5.. Train loss: 0.405.. Test loss: 1.586.. Test accuracy: 0.564
# Epoch 2/5.. Train loss: 0.481.. Test loss: 1.568.. Test accuracy: 0.566
# Epoch 2/5.. Train loss: 0.435.. Test loss: 1.530.. Test accuracy: 0.586
# Epoch 2/5.. Train loss: 0.493.. Test loss: 1.483.. Test accuracy: 0.606
# Epoch 2/5.. Train loss: 0.462.. Test loss: 1.472.. Test accuracy: 0.602
# Epoch 2/5.. Train loss: 0.477.. Test loss: 1.486.. Test accuracy: 0.603
# Epoch 2/5.. Train loss: 0.481.. Test loss: 1.520.. Test accuracy: 0.598
# Epoch 2/5.. Train loss: 0.473.. Test loss: 1.520.. Test accuracy: 0.597
# Epoch 2/5.. Train loss: 0.543.. Test loss: 1.537.. Test accuracy: 0.583
# Epoch 2/5.. Train loss: 0.412.. Test loss: 1.533.. Test accuracy: 0.585
# Epoch 2/5.. Train loss: 0.482.. Test loss: 1.513.. Test accuracy: 0.592
# Epoch 2/5.. Train loss: 0.449.. Test loss: 1.501.. Test accuracy: 0.578
# Epoch 2/5.. Train loss: 0.433.. Test loss: 1.486.. Test accuracy: 0.589
# Epoch 2/5.. Train loss: 0.518.. Test loss: 1.480.. Test accuracy: 0.601
# Epoch 2/5.. Train loss: 0.425.. Test loss: 1.466.. Test accuracy: 0.599
# Epoch 2/5.. Train loss: 0.536.. Test loss: 1.457.. Test accuracy: 0.599
# Epoch 2/5.. Train loss: 0.446.. Test loss: 1.466.. Test accuracy: 0.615
# Epoch 2/5.. Train loss: 0.443.. Test loss: 1.442.. Test accuracy: 0.619
# Epoch 2/5.. Train loss: 0.464.. Test loss: 1.414.. Test accuracy: 0.612
# Epoch 2/5.. Train loss: 0.403.. Test loss: 1.394.. Test accuracy: 0.617
# Epoch 2/5.. Train loss: 0.407.. Test loss: 1.384.. Test accuracy: 0.624
# Epoch 2/5.. Train loss: 0.507.. Test loss: 1.388.. Test accuracy: 0.635
# Epoch 2/5.. Train loss: 0.377.. Test loss: 1.397.. Test accuracy: 0.637
# Epoch 2/5.. Train loss: 0.349.. Test loss: 1.418.. Test accuracy: 0.628
# Epoch 2/5.. Train loss: 0.549.. Test loss: 1.419.. Test accuracy: 0.626
# Epoch 2/5.. Train loss: 0.374.. Test loss: 1.446.. Test accuracy: 0.623
# Epoch 2/5.. Train loss: 0.463.. Test loss: 1.476.. Test accuracy: 0.613
# Epoch 2/5.. Train loss: 0.542.. Test loss: 1.504.. Test accuracy: 0.606
# Epoch 2/5.. Train loss: 0.454.. Test loss: 1.539.. Test accuracy: 0.604
# Epoch 2/5.. Train loss: 0.477.. Test loss: 1.516.. Test accuracy: 0.626
# Epoch 2/5.. Train loss: 0.546.. Test loss: 1.488.. Test accuracy: 0.628
# Epoch 2/5.. Train loss: 0.484.. Test loss: 1.479.. Test accuracy: 0.619
# Epoch 2/5.. Train loss: 0.436.. Test loss: 1.422.. Test accuracy: 0.624
# Epoch 2/5.. Train loss: 0.442.. Test loss: 1.382.. Test accuracy: 0.625
# Epoch 2/5.. Train loss: 0.451.. Test loss: 1.392.. Test accuracy: 0.622
# Epoch 2/5.. Train loss: 0.517.. Test loss: 1.369.. Test accuracy: 0.625
# Epoch 2/5.. Train loss: 0.402.. Test loss: 1.380.. Test accuracy: 0.631
# Epoch 2/5.. Train loss: 0.438.. Test loss: 1.381.. Test accuracy: 0.644
# Epoch 2/5.. Train loss: 0.437.. Test loss: 1.390.. Test accuracy: 0.639
# Epoch 2/5.. Train loss: 0.454.. Test loss: 1.403.. Test accuracy: 0.644
# Epoch 2/5.. Train loss: 0.424.. Test loss: 1.373.. Test accuracy: 0.651
# Epoch 2/5.. Train loss: 0.466.. Test loss: 1.341.. Test accuracy: 0.657
# Epoch 2/5.. Train loss: 0.441.. Test loss: 1.328.. Test accuracy: 0.641
# Epoch 2/5.. Train loss: 0.529.. Test loss: 1.303.. Test accuracy: 0.644
# Epoch 2/5.. Train loss: 0.404.. Test loss: 1.298.. Test accuracy: 0.635
# Epoch 2/5.. Train loss: 0.470.. Test loss: 1.292.. Test accuracy: 0.639
# Epoch 2/5.. Train loss: 0.431.. Test loss: 1.291.. Test accuracy: 0.642
# Epoch 2/5.. Train loss: 0.424.. Test loss: 1.284.. Test accuracy: 0.643
# Epoch 2/5.. Train loss: 0.492.. Test loss: 1.291.. Test accuracy: 0.650
# Epoch 2/5.. Train loss: 0.382.. Test loss: 1.328.. Test accuracy: 0.636
# Epoch 2/5.. Train loss: 0.422.. Test loss: 1.352.. Test accuracy: 0.626
# Epoch 2/5.. Train loss: 0.439.. Test loss: 1.367.. Test accuracy: 0.617
# Epoch 2/5.. Train loss: 0.427.. Test loss: 1.353.. Test accuracy: 0.627
# Epoch 2/5.. Train loss: 0.481.. Test loss: 1.349.. Test accuracy: 0.624
# Epoch 2/5.. Train loss: 0.463.. Test loss: 1.354.. Test accuracy: 0.608
# Epoch 2/5.. Train loss: 0.471.. Test loss: 1.340.. Test accuracy: 0.625
# Epoch 2/5.. Train loss: 0.335.. Test loss: 1.344.. Test accuracy: 0.632
# Epoch 2/5.. Train loss: 0.512.. Test loss: 1.333.. Test accuracy: 0.644
# Epoch 2/5.. Train loss: 0.383.. Test loss: 1.321.. Test accuracy: 0.647
# Epoch 2/5.. Train loss: 0.441.. Test loss: 1.303.. Test accuracy: 0.653
# Epoch 2/5.. Train loss: 0.445.. Test loss: 1.278.. Test accuracy: 0.653
# Epoch 2/5.. Train loss: 0.453.. Test loss: 1.258.. Test accuracy: 0.651
# Epoch 2/5.. Train loss: 0.476.. Test loss: 1.244.. Test accuracy: 0.645
# Epoch 2/5.. Train loss: 0.436.. Test loss: 1.254.. Test accuracy: 0.641
# Epoch 2/5.. Train loss: 0.420.. Test loss: 1.258.. Test accuracy: 0.639
# Epoch 2/5.. Train loss: 0.340.. Test loss: 1.260.. Test accuracy: 0.639
# Epoch 2/5.. Train loss: 0.390.. Test loss: 1.273.. Test accuracy: 0.650
# Epoch 2/5.. Train loss: 0.332.. Test loss: 1.298.. Test accuracy: 0.642
# Epoch 2/5.. Train loss: 0.486.. Test loss: 1.296.. Test accuracy: 0.651
# Epoch 2/5.. Train loss: 0.343.. Test loss: 1.286.. Test accuracy: 0.655
# Epoch 2/5.. Train loss: 0.380.. Test loss: 1.285.. Test accuracy: 0.664
# Epoch 2/5.. Train loss: 0.329.. Test loss: 1.269.. Test accuracy: 0.659
# Epoch 2/5.. Train loss: 0.371.. Test loss: 1.254.. Test accuracy: 0.661
# Epoch 2/5.. Train loss: 0.401.. Test loss: 1.261.. Test accuracy: 0.662
# Epoch 2/5.. Train loss: 0.490.. Test loss: 1.282.. Test accuracy: 0.656
# Epoch 2/5.. Train loss: 0.328.. Test loss: 1.302.. Test accuracy: 0.649
# Epoch 2/5.. Train loss: 0.420.. Test loss: 1.335.. Test accuracy: 0.640
# Epoch 2/5.. Train loss: 0.304.. Test loss: 1.329.. Test accuracy: 0.637
# Epoch 2/5.. Train loss: 0.429.. Test loss: 1.315.. Test accuracy: 0.641
# Epoch 2/5.. Train loss: 0.397.. Test loss: 1.279.. Test accuracy: 0.651
# Epoch 2/5.. Train loss: 0.360.. Test loss: 1.255.. Test accuracy: 0.662
# Epoch 2/5.. Train loss: 0.539.. Test loss: 1.234.. Test accuracy: 0.661
# Epoch 3/5.. Train loss: 0.405.. Test loss: 1.227.. Test accuracy: 0.664
# Epoch 3/5.. Train loss: 0.369.. Test loss: 1.266.. Test accuracy: 0.653
# Epoch 3/5.. Train loss: 0.417.. Test loss: 1.316.. Test accuracy: 0.638
# Epoch 3/5.. Train loss: 0.373.. Test loss: 1.299.. Test accuracy: 0.639
# Epoch 3/5.. Train loss: 0.385.. Test loss: 1.253.. Test accuracy: 0.655
# Epoch 3/5.. Train loss: 0.353.. Test loss: 1.215.. Test accuracy: 0.668
# Epoch 3/5.. Train loss: 0.426.. Test loss: 1.189.. Test accuracy: 0.678
# Epoch 3/5.. Train loss: 0.433.. Test loss: 1.183.. Test accuracy: 0.674
# Epoch 3/5.. Train loss: 0.380.. Test loss: 1.207.. Test accuracy: 0.670
# Epoch 3/5.. Train loss: 0.447.. Test loss: 1.252.. Test accuracy: 0.664
# Epoch 3/5.. Train loss: 0.373.. Test loss: 1.291.. Test accuracy: 0.661
# Epoch 3/5.. Train loss: 0.392.. Test loss: 1.290.. Test accuracy: 0.662
# Epoch 3/5.. Train loss: 0.418.. Test loss: 1.262.. Test accuracy: 0.663
# Epoch 3/5.. Train loss: 0.316.. Test loss: 1.252.. Test accuracy: 0.665
# Epoch 3/5.. Train loss: 0.335.. Test loss: 1.242.. Test accuracy: 0.663
# Epoch 3/5.. Train loss: 0.335.. Test loss: 1.242.. Test accuracy: 0.655
# Epoch 3/5.. Train loss: 0.428.. Test loss: 1.231.. Test accuracy: 0.661
# Epoch 3/5.. Train loss: 0.384.. Test loss: 1.219.. Test accuracy: 0.684
# Epoch 3/5.. Train loss: 0.272.. Test loss: 1.213.. Test accuracy: 0.682
# Epoch 3/5.. Train loss: 0.399.. Test loss: 1.198.. Test accuracy: 0.678
# Epoch 3/5.. Train loss: 0.442.. Test loss: 1.196.. Test accuracy: 0.668
# Epoch 3/5.. Train loss: 0.406.. Test loss: 1.216.. Test accuracy: 0.666
# Epoch 3/5.. Train loss: 0.357.. Test loss: 1.243.. Test accuracy: 0.654
# Epoch 3/5.. Train loss: 0.367.. Test loss: 1.251.. Test accuracy: 0.657
# Epoch 3/5.. Train loss: 0.368.. Test loss: 1.245.. Test accuracy: 0.664
# Epoch 3/5.. Train loss: 0.322.. Test loss: 1.233.. Test accuracy: 0.666
# Epoch 3/5.. Train loss: 0.416.. Test loss: 1.217.. Test accuracy: 0.665
# Epoch 3/5.. Train loss: 0.352.. Test loss: 1.198.. Test accuracy: 0.665
# Epoch 3/5.. Train loss: 0.376.. Test loss: 1.173.. Test accuracy: 0.671
# Epoch 3/5.. Train loss: 0.461.. Test loss: 1.154.. Test accuracy: 0.679
# Epoch 3/5.. Train loss: 0.418.. Test loss: 1.143.. Test accuracy: 0.680
# Epoch 3/5.. Train loss: 0.381.. Test loss: 1.123.. Test accuracy: 0.695
# Epoch 3/5.. Train loss: 0.392.. Test loss: 1.120.. Test accuracy: 0.694
# Epoch 3/5.. Train loss: 0.416.. Test loss: 1.109.. Test accuracy: 0.705
# Epoch 3/5.. Train loss: 0.423.. Test loss: 1.112.. Test accuracy: 0.706
# Epoch 3/5.. Train loss: 0.420.. Test loss: 1.122.. Test accuracy: 0.710
# Epoch 3/5.. Train loss: 0.400.. Test loss: 1.145.. Test accuracy: 0.711
# Epoch 3/5.. Train loss: 0.374.. Test loss: 1.162.. Test accuracy: 0.692
# Epoch 3/5.. Train loss: 0.478.. Test loss: 1.174.. Test accuracy: 0.689
# Epoch 3/5.. Train loss: 0.410.. Test loss: 1.179.. Test accuracy: 0.680
# Epoch 3/5.. Train loss: 0.356.. Test loss: 1.170.. Test accuracy: 0.691
# Epoch 3/5.. Train loss: 0.402.. Test loss: 1.167.. Test accuracy: 0.693
# Epoch 3/5.. Train loss: 0.326.. Test loss: 1.171.. Test accuracy: 0.693
# Epoch 3/5.. Train loss: 0.444.. Test loss: 1.167.. Test accuracy: 0.697
# Epoch 3/5.. Train loss: 0.340.. Test loss: 1.178.. Test accuracy: 0.690
# Epoch 3/5.. Train loss: 0.348.. Test loss: 1.207.. Test accuracy: 0.683
# Epoch 3/5.. Train loss: 0.436.. Test loss: 1.222.. Test accuracy: 0.680
# Epoch 3/5.. Train loss: 0.328.. Test loss: 1.245.. Test accuracy: 0.675
# Epoch 3/5.. Train loss: 0.388.. Test loss: 1.240.. Test accuracy: 0.681
# Epoch 3/5.. Train loss: 0.345.. Test loss: 1.240.. Test accuracy: 0.679
# Epoch 3/5.. Train loss: 0.372.. Test loss: 1.207.. Test accuracy: 0.683
# Epoch 3/5.. Train loss: 0.399.. Test loss: 1.180.. Test accuracy: 0.692
# Epoch 3/5.. Train loss: 0.441.. Test loss: 1.155.. Test accuracy: 0.699
# Epoch 3/5.. Train loss: 0.329.. Test loss: 1.158.. Test accuracy: 0.702
# Epoch 3/5.. Train loss: 0.408.. Test loss: 1.166.. Test accuracy: 0.682
# Epoch 3/5.. Train loss: 0.338.. Test loss: 1.176.. Test accuracy: 0.671
# Epoch 3/5.. Train loss: 0.457.. Test loss: 1.182.. Test accuracy: 0.669
# Epoch 3/5.. Train loss: 0.431.. Test loss: 1.202.. Test accuracy: 0.664
# Epoch 3/5.. Train loss: 0.342.. Test loss: 1.215.. Test accuracy: 0.670
# Epoch 3/5.. Train loss: 0.335.. Test loss: 1.236.. Test accuracy: 0.671
# Epoch 3/5.. Train loss: 0.399.. Test loss: 1.259.. Test accuracy: 0.673
# Epoch 3/5.. Train loss: 0.333.. Test loss: 1.247.. Test accuracy: 0.671
# Epoch 3/5.. Train loss: 0.426.. Test loss: 1.205.. Test accuracy: 0.681
# Epoch 3/5.. Train loss: 0.323.. Test loss: 1.198.. Test accuracy: 0.681
# Epoch 3/5.. Train loss: 0.370.. Test loss: 1.213.. Test accuracy: 0.672
# Epoch 3/5.. Train loss: 0.412.. Test loss: 1.227.. Test accuracy: 0.666
# Epoch 3/5.. Train loss: 0.348.. Test loss: 1.235.. Test accuracy: 0.666
# Epoch 3/5.. Train loss: 0.493.. Test loss: 1.252.. Test accuracy: 0.661
# Epoch 3/5.. Train loss: 0.451.. Test loss: 1.256.. Test accuracy: 0.655
# Epoch 3/5.. Train loss: 0.467.. Test loss: 1.250.. Test accuracy: 0.653
# Epoch 3/5.. Train loss: 0.418.. Test loss: 1.265.. Test accuracy: 0.656
# Epoch 3/5.. Train loss: 0.338.. Test loss: 1.312.. Test accuracy: 0.648
# Epoch 3/5.. Train loss: 0.341.. Test loss: 1.342.. Test accuracy: 0.647
# Epoch 3/5.. Train loss: 0.386.. Test loss: 1.347.. Test accuracy: 0.658
# Epoch 3/5.. Train loss: 0.330.. Test loss: 1.272.. Test accuracy: 0.662
# Epoch 3/5.. Train loss: 0.433.. Test loss: 1.205.. Test accuracy: 0.677
# Epoch 3/5.. Train loss: 0.346.. Test loss: 1.177.. Test accuracy: 0.685
# Epoch 3/5.. Train loss: 0.397.. Test loss: 1.152.. Test accuracy: 0.690
# Epoch 3/5.. Train loss: 0.399.. Test loss: 1.127.. Test accuracy: 0.698
# Epoch 3/5.. Train loss: 0.307.. Test loss: 1.112.. Test accuracy: 0.692
# Epoch 3/5.. Train loss: 0.422.. Test loss: 1.127.. Test accuracy: 0.684
# Epoch 3/5.. Train loss: 0.342.. Test loss: 1.151.. Test accuracy: 0.683
# Epoch 3/5.. Train loss: 0.432.. Test loss: 1.156.. Test accuracy: 0.684
# Epoch 3/5.. Train loss: 0.472.. Test loss: 1.156.. Test accuracy: 0.684
# Epoch 3/5.. Train loss: 0.387.. Test loss: 1.150.. Test accuracy: 0.680
# Epoch 3/5.. Train loss: 0.388.. Test loss: 1.126.. Test accuracy: 0.693
# Epoch 3/5.. Train loss: 0.400.. Test loss: 1.105.. Test accuracy: 0.698
# Epoch 3/5.. Train loss: 0.402.. Test loss: 1.104.. Test accuracy: 0.697
# Epoch 3/5.. Train loss: 0.512.. Test loss: 1.102.. Test accuracy: 0.697
# Epoch 3/5.. Train loss: 0.446.. Test loss: 1.103.. Test accuracy: 0.692
# Epoch 3/5.. Train loss: 0.395.. Test loss: 1.120.. Test accuracy: 0.692
# Epoch 3/5.. Train loss: 0.362.. Test loss: 1.132.. Test accuracy: 0.696
# Epoch 3/5.. Train loss: 0.304.. Test loss: 1.151.. Test accuracy: 0.684
# Epoch 3/5.. Train loss: 0.381.. Test loss: 1.168.. Test accuracy: 0.678
# Epoch 3/5.. Train loss: 0.289.. Test loss: 1.177.. Test accuracy: 0.683
# Epoch 3/5.. Train loss: 0.376.. Test loss: 1.197.. Test accuracy: 0.685
# Epoch 3/5.. Train loss: 0.376.. Test loss: 1.195.. Test accuracy: 0.689
# Epoch 3/5.. Train loss: 0.348.. Test loss: 1.174.. Test accuracy: 0.696
# Epoch 3/5.. Train loss: 0.394.. Test loss: 1.170.. Test accuracy: 0.702
# Epoch 3/5.. Train loss: 0.405.. Test loss: 1.143.. Test accuracy: 0.707
# Epoch 3/5.. Train loss: 0.379.. Test loss: 1.142.. Test accuracy: 0.690
# Epoch 3/5.. Train loss: 0.312.. Test loss: 1.158.. Test accuracy: 0.677
# Epoch 3/5.. Train loss: 0.410.. Test loss: 1.171.. Test accuracy: 0.675
# Epoch 4/5.. Train loss: 0.543.. Test loss: 1.186.. Test accuracy: 0.676
# Epoch 4/5.. Train loss: 0.353.. Test loss: 1.189.. Test accuracy: 0.676
# Epoch 4/5.. Train loss: 0.455.. Test loss: 1.199.. Test accuracy: 0.686
# Epoch 4/5.. Train loss: 0.334.. Test loss: 1.216.. Test accuracy: 0.681
# Epoch 4/5.. Train loss: 0.400.. Test loss: 1.231.. Test accuracy: 0.680
# Epoch 4/5.. Train loss: 0.454.. Test loss: 1.245.. Test accuracy: 0.682
# Epoch 4/5.. Train loss: 0.422.. Test loss: 1.245.. Test accuracy: 0.674
# Epoch 4/5.. Train loss: 0.413.. Test loss: 1.234.. Test accuracy: 0.681
# Epoch 4/5.. Train loss: 0.431.. Test loss: 1.214.. Test accuracy: 0.681
# Epoch 4/5.. Train loss: 0.463.. Test loss: 1.192.. Test accuracy: 0.688
# Epoch 4/5.. Train loss: 0.428.. Test loss: 1.183.. Test accuracy: 0.689
# Epoch 4/5.. Train loss: 0.288.. Test loss: 1.170.. Test accuracy: 0.682
# Epoch 4/5.. Train loss: 0.363.. Test loss: 1.165.. Test accuracy: 0.693
# Epoch 4/5.. Train loss: 0.386.. Test loss: 1.163.. Test accuracy: 0.689
# Epoch 4/5.. Train loss: 0.429.. Test loss: 1.155.. Test accuracy: 0.686
# Epoch 4/5.. Train loss: 0.424.. Test loss: 1.166.. Test accuracy: 0.678
# Epoch 4/5.. Train loss: 0.471.. Test loss: 1.180.. Test accuracy: 0.674
# Epoch 4/5.. Train loss: 0.360.. Test loss: 1.188.. Test accuracy: 0.677
# Epoch 4/5.. Train loss: 0.385.. Test loss: 1.169.. Test accuracy: 0.684
# Epoch 4/5.. Train loss: 0.490.. Test loss: 1.132.. Test accuracy: 0.694
# Epoch 4/5.. Train loss: 0.383.. Test loss: 1.126.. Test accuracy: 0.694
# Epoch 4/5.. Train loss: 0.400.. Test loss: 1.133.. Test accuracy: 0.691
# Epoch 4/5.. Train loss: 0.251.. Test loss: 1.140.. Test accuracy: 0.697
# Epoch 4/5.. Train loss: 0.265.. Test loss: 1.142.. Test accuracy: 0.683
# Epoch 4/5.. Train loss: 0.319.. Test loss: 1.125.. Test accuracy: 0.690
# Epoch 4/5.. Train loss: 0.289.. Test loss: 1.122.. Test accuracy: 0.697
# Epoch 4/5.. Train loss: 0.363.. Test loss: 1.125.. Test accuracy: 0.688
# Epoch 4/5.. Train loss: 0.379.. Test loss: 1.119.. Test accuracy: 0.690
# Epoch 4/5.. Train loss: 0.395.. Test loss: 1.088.. Test accuracy: 0.698
# Epoch 4/5.. Train loss: 0.355.. Test loss: 1.067.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.457.. Test loss: 1.050.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.373.. Test loss: 1.039.. Test accuracy: 0.717
# Epoch 4/5.. Train loss: 0.393.. Test loss: 1.034.. Test accuracy: 0.724
# Epoch 4/5.. Train loss: 0.379.. Test loss: 1.042.. Test accuracy: 0.722
# Epoch 4/5.. Train loss: 0.382.. Test loss: 1.041.. Test accuracy: 0.726
# Epoch 4/5.. Train loss: 0.355.. Test loss: 1.052.. Test accuracy: 0.716
# Epoch 4/5.. Train loss: 0.414.. Test loss: 1.050.. Test accuracy: 0.721
# Epoch 4/5.. Train loss: 0.379.. Test loss: 1.057.. Test accuracy: 0.716
# Epoch 4/5.. Train loss: 0.405.. Test loss: 1.063.. Test accuracy: 0.712
# Epoch 4/5.. Train loss: 0.338.. Test loss: 1.065.. Test accuracy: 0.716
# Epoch 4/5.. Train loss: 0.376.. Test loss: 1.071.. Test accuracy: 0.724
# Epoch 4/5.. Train loss: 0.313.. Test loss: 1.076.. Test accuracy: 0.722
# Epoch 4/5.. Train loss: 0.365.. Test loss: 1.078.. Test accuracy: 0.725
# Epoch 4/5.. Train loss: 0.358.. Test loss: 1.085.. Test accuracy: 0.706
# Epoch 4/5.. Train loss: 0.320.. Test loss: 1.080.. Test accuracy: 0.708
# Epoch 4/5.. Train loss: 0.388.. Test loss: 1.077.. Test accuracy: 0.719
# Epoch 4/5.. Train loss: 0.272.. Test loss: 1.071.. Test accuracy: 0.720
# Epoch 4/5.. Train loss: 0.360.. Test loss: 1.054.. Test accuracy: 0.726
# Epoch 4/5.. Train loss: 0.266.. Test loss: 1.047.. Test accuracy: 0.720
# Epoch 4/5.. Train loss: 0.326.. Test loss: 1.041.. Test accuracy: 0.718
# Epoch 4/5.. Train loss: 0.370.. Test loss: 1.035.. Test accuracy: 0.720
# Epoch 4/5.. Train loss: 0.363.. Test loss: 1.032.. Test accuracy: 0.715
# Epoch 4/5.. Train loss: 0.445.. Test loss: 1.036.. Test accuracy: 0.712
# Epoch 4/5.. Train loss: 0.451.. Test loss: 1.024.. Test accuracy: 0.720
# Epoch 4/5.. Train loss: 0.334.. Test loss: 1.028.. Test accuracy: 0.727
# Epoch 4/5.. Train loss: 0.255.. Test loss: 1.044.. Test accuracy: 0.715
# Epoch 4/5.. Train loss: 0.393.. Test loss: 1.059.. Test accuracy: 0.712
# Epoch 4/5.. Train loss: 0.337.. Test loss: 1.094.. Test accuracy: 0.692
# Epoch 4/5.. Train loss: 0.412.. Test loss: 1.124.. Test accuracy: 0.689
# Epoch 4/5.. Train loss: 0.444.. Test loss: 1.126.. Test accuracy: 0.697
# Epoch 4/5.. Train loss: 0.460.. Test loss: 1.106.. Test accuracy: 0.703
# Epoch 4/5.. Train loss: 0.322.. Test loss: 1.080.. Test accuracy: 0.705
# Epoch 4/5.. Train loss: 0.360.. Test loss: 1.083.. Test accuracy: 0.707
# Epoch 4/5.. Train loss: 0.436.. Test loss: 1.100.. Test accuracy: 0.713
# Epoch 4/5.. Train loss: 0.495.. Test loss: 1.110.. Test accuracy: 0.708
# Epoch 4/5.. Train loss: 0.330.. Test loss: 1.106.. Test accuracy: 0.711
# Epoch 4/5.. Train loss: 0.352.. Test loss: 1.101.. Test accuracy: 0.711
# Epoch 4/5.. Train loss: 0.424.. Test loss: 1.101.. Test accuracy: 0.707
# Epoch 4/5.. Train loss: 0.387.. Test loss: 1.092.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.325.. Test loss: 1.079.. Test accuracy: 0.712
# Epoch 4/5.. Train loss: 0.403.. Test loss: 1.072.. Test accuracy: 0.714
# Epoch 4/5.. Train loss: 0.361.. Test loss: 1.070.. Test accuracy: 0.717
# Epoch 4/5.. Train loss: 0.362.. Test loss: 1.070.. Test accuracy: 0.717
# Epoch 4/5.. Train loss: 0.318.. Test loss: 1.066.. Test accuracy: 0.720
# Epoch 4/5.. Train loss: 0.343.. Test loss: 1.057.. Test accuracy: 0.718
# Epoch 4/5.. Train loss: 0.323.. Test loss: 1.059.. Test accuracy: 0.713
# Epoch 4/5.. Train loss: 0.450.. Test loss: 1.059.. Test accuracy: 0.707
# Epoch 4/5.. Train loss: 0.359.. Test loss: 1.051.. Test accuracy: 0.711
# Epoch 4/5.. Train loss: 0.470.. Test loss: 1.038.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.355.. Test loss: 1.031.. Test accuracy: 0.713
# Epoch 4/5.. Train loss: 0.393.. Test loss: 1.028.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.330.. Test loss: 1.020.. Test accuracy: 0.717
# Epoch 4/5.. Train loss: 0.384.. Test loss: 1.007.. Test accuracy: 0.720
# Epoch 4/5.. Train loss: 0.401.. Test loss: 0.999.. Test accuracy: 0.716
# Epoch 4/5.. Train loss: 0.402.. Test loss: 0.991.. Test accuracy: 0.722
# Epoch 4/5.. Train loss: 0.264.. Test loss: 0.985.. Test accuracy: 0.728
# Epoch 4/5.. Train loss: 0.348.. Test loss: 0.987.. Test accuracy: 0.721
# Epoch 4/5.. Train loss: 0.358.. Test loss: 0.996.. Test accuracy: 0.717
# Epoch 4/5.. Train loss: 0.427.. Test loss: 1.010.. Test accuracy: 0.706
# Epoch 4/5.. Train loss: 0.368.. Test loss: 1.029.. Test accuracy: 0.698
# Epoch 4/5.. Train loss: 0.384.. Test loss: 1.037.. Test accuracy: 0.706
# Epoch 4/5.. Train loss: 0.444.. Test loss: 1.036.. Test accuracy: 0.712
# Epoch 4/5.. Train loss: 0.289.. Test loss: 1.046.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.276.. Test loss: 1.060.. Test accuracy: 0.707
# Epoch 4/5.. Train loss: 0.356.. Test loss: 1.077.. Test accuracy: 0.699
# Epoch 4/5.. Train loss: 0.378.. Test loss: 1.069.. Test accuracy: 0.709
# Epoch 4/5.. Train loss: 0.271.. Test loss: 1.057.. Test accuracy: 0.707
# Epoch 4/5.. Train loss: 0.402.. Test loss: 1.053.. Test accuracy: 0.704
# Epoch 4/5.. Train loss: 0.393.. Test loss: 1.045.. Test accuracy: 0.707
# Epoch 4/5.. Train loss: 0.405.. Test loss: 1.039.. Test accuracy: 0.709
# Epoch 4/5.. Train loss: 0.348.. Test loss: 1.040.. Test accuracy: 0.714
# Epoch 4/5.. Train loss: 0.323.. Test loss: 1.037.. Test accuracy: 0.710
# Epoch 4/5.. Train loss: 0.251.. Test loss: 1.031.. Test accuracy: 0.712
# Epoch 5/5.. Train loss: 0.359.. Test loss: 1.041.. Test accuracy: 0.713
# Epoch 5/5.. Train loss: 0.288.. Test loss: 1.053.. Test accuracy: 0.714
# Epoch 5/5.. Train loss: 0.329.. Test loss: 1.084.. Test accuracy: 0.708
# Epoch 5/5.. Train loss: 0.407.. Test loss: 1.129.. Test accuracy: 0.702
# Epoch 5/5.. Train loss: 0.383.. Test loss: 1.146.. Test accuracy: 0.701
# Epoch 5/5.. Train loss: 0.415.. Test loss: 1.156.. Test accuracy: 0.687
# Epoch 5/5.. Train loss: 0.380.. Test loss: 1.159.. Test accuracy: 0.688
# Epoch 5/5.. Train loss: 0.413.. Test loss: 1.137.. Test accuracy: 0.697
# Epoch 5/5.. Train loss: 0.441.. Test loss: 1.097.. Test accuracy: 0.706
# Epoch 5/5.. Train loss: 0.351.. Test loss: 1.085.. Test accuracy: 0.719
# Epoch 5/5.. Train loss: 0.339.. Test loss: 1.084.. Test accuracy: 0.709
# Epoch 5/5.. Train loss: 0.305.. Test loss: 1.092.. Test accuracy: 0.706
# Epoch 5/5.. Train loss: 0.445.. Test loss: 1.099.. Test accuracy: 0.714
# Epoch 5/5.. Train loss: 0.336.. Test loss: 1.107.. Test accuracy: 0.713
# Epoch 5/5.. Train loss: 0.429.. Test loss: 1.115.. Test accuracy: 0.708
# Epoch 5/5.. Train loss: 0.378.. Test loss: 1.115.. Test accuracy: 0.714
# Epoch 5/5.. Train loss: 0.354.. Test loss: 1.108.. Test accuracy: 0.703
# Epoch 5/5.. Train loss: 0.324.. Test loss: 1.109.. Test accuracy: 0.701
# Epoch 5/5.. Train loss: 0.330.. Test loss: 1.122.. Test accuracy: 0.696
# Epoch 5/5.. Train loss: 0.384.. Test loss: 1.147.. Test accuracy: 0.689
# Epoch 5/5.. Train loss: 0.370.. Test loss: 1.153.. Test accuracy: 0.695
# Epoch 5/5.. Train loss: 0.402.. Test loss: 1.157.. Test accuracy: 0.694
# Epoch 5/5.. Train loss: 0.480.. Test loss: 1.154.. Test accuracy: 0.697
# Epoch 5/5.. Train loss: 0.338.. Test loss: 1.151.. Test accuracy: 0.692
# Epoch 5/5.. Train loss: 0.446.. Test loss: 1.124.. Test accuracy: 0.703
# Epoch 5/5.. Train loss: 0.347.. Test loss: 1.098.. Test accuracy: 0.707
# Epoch 5/5.. Train loss: 0.425.. Test loss: 1.077.. Test accuracy: 0.711
# Epoch 5/5.. Train loss: 0.329.. Test loss: 1.069.. Test accuracy: 0.718
# Epoch 5/5.. Train loss: 0.368.. Test loss: 1.065.. Test accuracy: 0.716
# Epoch 5/5.. Train loss: 0.456.. Test loss: 1.066.. Test accuracy: 0.719
# Epoch 5/5.. Train loss: 0.283.. Test loss: 1.071.. Test accuracy: 0.719
# Epoch 5/5.. Train loss: 0.399.. Test loss: 1.081.. Test accuracy: 0.714
# Epoch 5/5.. Train loss: 0.332.. Test loss: 1.094.. Test accuracy: 0.712
# Epoch 5/5.. Train loss: 0.416.. Test loss: 1.108.. Test accuracy: 0.703
# Epoch 5/5.. Train loss: 0.343.. Test loss: 1.120.. Test accuracy: 0.703
# Epoch 5/5.. Train loss: 0.409.. Test loss: 1.137.. Test accuracy: 0.697
# Epoch 5/5.. Train loss: 0.371.. Test loss: 1.166.. Test accuracy: 0.698
# Epoch 5/5.. Train loss: 0.360.. Test loss: 1.188.. Test accuracy: 0.694
# Epoch 5/5.. Train loss: 0.380.. Test loss: 1.204.. Test accuracy: 0.686
# Epoch 5/5.. Train loss: 0.444.. Test loss: 1.211.. Test accuracy: 0.684
# Epoch 5/5.. Train loss: 0.368.. Test loss: 1.224.. Test accuracy: 0.680
# Epoch 5/5.. Train loss: 0.472.. Test loss: 1.228.. Test accuracy: 0.681
# Epoch 5/5.. Train loss: 0.315.. Test loss: 1.217.. Test accuracy: 0.690
# Epoch 5/5.. Train loss: 0.286.. Test loss: 1.204.. Test accuracy: 0.688
# Epoch 5/5.. Train loss: 0.463.. Test loss: 1.172.. Test accuracy: 0.686
# Epoch 5/5.. Train loss: 0.347.. Test loss: 1.144.. Test accuracy: 0.684
# Epoch 5/5.. Train loss: 0.385.. Test loss: 1.119.. Test accuracy: 0.695
# Epoch 5/5.. Train loss: 0.332.. Test loss: 1.093.. Test accuracy: 0.703
# Epoch 5/5.. Train loss: 0.350.. Test loss: 1.082.. Test accuracy: 0.700
# Epoch 5/5.. Train loss: 0.265.. Test loss: 1.079.. Test accuracy: 0.701
# Epoch 5/5.. Train loss: 0.404.. Test loss: 1.072.. Test accuracy: 0.705
# Epoch 5/5.. Train loss: 0.252.. Test loss: 1.055.. Test accuracy: 0.720
# Epoch 5/5.. Train loss: 0.326.. Test loss: 1.038.. Test accuracy: 0.739
# Epoch 5/5.. Train loss: 0.377.. Test loss: 1.032.. Test accuracy: 0.741
# Epoch 5/5.. Train loss: 0.300.. Test loss: 1.020.. Test accuracy: 0.740
# Epoch 5/5.. Train loss: 0.254.. Test loss: 1.009.. Test accuracy: 0.745
# Epoch 5/5.. Train loss: 0.271.. Test loss: 1.009.. Test accuracy: 0.745
# Epoch 5/5.. Train loss: 0.355.. Test loss: 1.013.. Test accuracy: 0.746
# Epoch 5/5.. Train loss: 0.358.. Test loss: 1.021.. Test accuracy: 0.746
# Epoch 5/5.. Train loss: 0.337.. Test loss: 1.021.. Test accuracy: 0.740
# Epoch 5/5.. Train loss: 0.324.. Test loss: 1.032.. Test accuracy: 0.738
# Epoch 5/5.. Train loss: 0.375.. Test loss: 1.039.. Test accuracy: 0.735
# Epoch 5/5.. Train loss: 0.365.. Test loss: 1.051.. Test accuracy: 0.733
# Epoch 5/5.. Train loss: 0.369.. Test loss: 1.066.. Test accuracy: 0.732
# Epoch 5/5.. Train loss: 0.353.. Test loss: 1.079.. Test accuracy: 0.734
# Epoch 5/5.. Train loss: 0.404.. Test loss: 1.074.. Test accuracy: 0.738
# Epoch 5/5.. Train loss: 0.421.. Test loss: 1.069.. Test accuracy: 0.746
# Epoch 5/5.. Train loss: 0.375.. Test loss: 1.065.. Test accuracy: 0.753
# Epoch 5/5.. Train loss: 0.322.. Test loss: 1.065.. Test accuracy: 0.755
# Epoch 5/5.. Train loss: 0.315.. Test loss: 1.068.. Test accuracy: 0.754
# Epoch 5/5.. Train loss: 0.362.. Test loss: 1.069.. Test accuracy: 0.758
# Epoch 5/5.. Train loss: 0.395.. Test loss: 1.069.. Test accuracy: 0.751
# Epoch 5/5.. Train loss: 0.328.. Test loss: 1.072.. Test accuracy: 0.740
# Epoch 5/5.. Train loss: 0.321.. Test loss: 1.083.. Test accuracy: 0.736
# Epoch 5/5.. Train loss: 0.311.. Test loss: 1.097.. Test accuracy: 0.732
# Epoch 5/5.. Train loss: 0.433.. Test loss: 1.119.. Test accuracy: 0.724
# Epoch 5/5.. Train loss: 0.379.. Test loss: 1.118.. Test accuracy: 0.726
# Epoch 5/5.. Train loss: 0.374.. Test loss: 1.111.. Test accuracy: 0.730
# Epoch 5/5.. Train loss: 0.359.. Test loss: 1.098.. Test accuracy: 0.736
# Epoch 5/5.. Train loss: 0.359.. Test loss: 1.088.. Test accuracy: 0.739
# Epoch 5/5.. Train loss: 0.268.. Test loss: 1.076.. Test accuracy: 0.741
# Epoch 5/5.. Train loss: 0.359.. Test loss: 1.070.. Test accuracy: 0.735
# Epoch 5/5.. Train loss: 0.376.. Test loss: 1.060.. Test accuracy: 0.735
# Epoch 5/5.. Train loss: 0.391.. Test loss: 1.053.. Test accuracy: 0.730
# Epoch 5/5.. Train loss: 0.475.. Test loss: 1.052.. Test accuracy: 0.734
# Epoch 5/5.. Train loss: 0.315.. Test loss: 1.060.. Test accuracy: 0.738
# Epoch 5/5.. Train loss: 0.338.. Test loss: 1.073.. Test accuracy: 0.739
# Epoch 5/5.. Train loss: 0.360.. Test loss: 1.076.. Test accuracy: 0.725
# Epoch 5/5.. Train loss: 0.310.. Test loss: 1.093.. Test accuracy: 0.719
# Epoch 5/5.. Train loss: 0.439.. Test loss: 1.108.. Test accuracy: 0.717
# Epoch 5/5.. Train loss: 0.283.. Test loss: 1.126.. Test accuracy: 0.727
# Epoch 5/5.. Train loss: 0.391.. Test loss: 1.117.. Test accuracy: 0.731
# Epoch 5/5.. Train loss: 0.347.. Test loss: 1.111.. Test accuracy: 0.731
# Epoch 5/5.. Train loss: 0.335.. Test loss: 1.097.. Test accuracy: 0.731
# Epoch 5/5.. Train loss: 0.416.. Test loss: 1.077.. Test accuracy: 0.742
# Epoch 5/5.. Train loss: 0.367.. Test loss: 1.057.. Test accuracy: 0.734
# Epoch 5/5.. Train loss: 0.286.. Test loss: 1.044.. Test accuracy: 0.735
# Epoch 5/5.. Train loss: 0.412.. Test loss: 1.028.. Test accuracy: 0.740
# Epoch 5/5.. Train loss: 0.348.. Test loss: 1.020.. Test accuracy: 0.735
# Epoch 5/5.. Train loss: 0.330.. Test loss: 1.013.. Test accuracy: 0.735
# Epoch 5/5.. Train loss: 0.366.. Test loss: 1.021.. Test accuracy: 0.742
# Epoch 5/5.. Train loss: 0.409.. Test loss: 1.032.. Test accuracy: 0.744
# Epoch 5/5.. Train loss: 0.233.. Test loss: 1.051.. Test accuracy: 0.736

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# DONE: Do validation on the test set

#####################
# Test the model
#####################

test_loss = 0
accuracy = 0

# Set the model to evaluation mode (turns off dropout)
model.eval()

# Turn off gradients for validation to save memory and computations
with torch.no_grad():
    for images, labels in dataloaders['test']:

        # Move input and label tensors to the default device
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        logps = model.forward(images)
        batch_loss = criterion(logps, labels)

        test_loss += batch_loss.item()

        # Calculate accuracy
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(1, dim=1)
        equality = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equality.type(torch.FloatTensor)).item()

# Print the results
print(f"Test Loss: {test_loss/len(dataloaders['test']):.3f}.. "
      f"Test Accuracy: {accuracy/len(dataloaders['test']):.3f}")
# Out:
# Test Loss: 1.117.. Test Accuracy: 0.702

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# DONE: Save the checkpoint

#####################
# Save Checkpoint
#####################

model.class_to_idx = image_datasets['train'].class_to_idx

checkpoint = {
    'arch': 'vgg16',
    'input_size': 25088,
    'output_size': 102,
    'hidden_layers': [4096, 512],
    'state_dict': model.state_dict(),
    'class_to_idx': model.class_to_idx,
    'optimizer_state': optimizer.state_dict(),
    'epoch': epochs
}

torch.save(checkpoint, 'checkpoints/image_classifier_checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# DONE: Write a function that loads a checkpoint and rebuilds the model

#####################
# Loading Checkpoint
#####################

def load_checkpoint_vgg16(filepath):

    # Load the checkpoint dictionary
    checkpoint = torch.load(filepath, map_location='cpu')

    # Rebuild the base architecture (using the string we saved earlier)
    if checkpoint['arch'] == 'vgg16':
        model = models.vgg16(weights=models.VGG16_Weights.DEFAULT)
    else:
        print("Architecture not recognized.")
        return None
    # Freeze the parameters of the base model
    for param in model.parameters():
        param.requires_grad = False
    # Rebuild the custom classifier as it was
    classifier = nn.Sequential(
        nn.Linear(checkpoint['input_size'], checkpoint['hidden_layers'][0]),
        nn.ReLU(),
        nn.Dropout(p=0.2),
        nn.Linear(checkpoint['hidden_layers'][0], checkpoint['hidden_layers'][1]),
        nn.ReLU(),
        nn.Dropout(p=0.2),
        nn.Linear(checkpoint['hidden_layers'][1], checkpoint['output_size']),
        nn.LogSoftmax(dim=1)
    )
    # Attach the reconstructed classifier to the model
    model.classifier = classifier

    # Load the trained weights (the state_dict)
    model.load_state_dict(checkpoint['state_dict'])

    # Attach the class_to_idx mapping
    model.class_to_idx = checkpoint['class_to_idx']

    return model

model = load_checkpoint_vgg16('checkpoints/image_classifier_checkpoint.pth')
#model.to(device)

print("Our model: \n\n", model, '\n')
print("The state dict keys: \n\n", model.state_dict().keys())
# Out:
# Our model:
#
#  VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=4096, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=512, out_features=102, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )
#
# The state dict keys:
#
#  odict_keys(['features.0.weight', 'features.0.bias', 'features.2.weight', 'features.2.bias', 'features.5.weight', 'features.5.bias', 'features.7.weight', 'features.7.bias', 'features.10.weight', 'features.10.bias', 'features.12.weight', 'features.12.bias', 'features.14.weight', 'features.14.bias', 'features.17.weight', 'features.17.bias', 'features.19.weight', 'features.19.bias', 'features.21.weight', 'features.21.bias', 'features.24.weight', 'features.24.bias', 'features.26.weight', 'features.26.bias', 'features.28.weight', 'features.28.bias', 'classifier.0.weight', 'classifier.0.bias', 'classifier.3.weight', 'classifier.3.bias', 'classifier.6.weight', 'classifier.6.bias'])

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns the image as a FloatTensor ready to be used in a PyTorch model.
    '''
    
    # DONE: Process a PIL image for use in a PyTorch model

    # Resize: The shortest side is 256 pixels, keeping the aspect ratio.
    width, height = image.size
    aspect_ratio = width / height

    if width < height:
        new_width = 256
        new_height = int(new_width / aspect_ratio)
    else:
        new_height = 256
        new_width = int(new_height * aspect_ratio)

    image = image.resize((new_width, new_height))

    # Crop: Center 224x224 portion of the image.
    left = (new_width - 224) / 2
    top = (new_height - 224) / 2
    right = (new_width + 224) / 2
    bottom = (new_height + 224) / 2
    image = image.crop((left, top, right, bottom))

    # Normalize values to 0-1
    np_image = np.array(image) / 255.0

    # Normalize with specific means and standard deviations
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_image = (np_image - mean) / std

    # Reorder dimensions from (H, W, C) to (C, H, W)
    np_image = np_image.transpose((2, 0, 1))

    return torch.from_numpy(np_image).type(torch.FloatTensor)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
# Load the image using PIL and process it
image_path = 'data/flowers/test/4/image_05637.jpg'
pil_image = Image.open(image_path)
image = process_image(pil_image)

# Use the imshow method to display the image
imshow(image)
# Out:
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # DONE: Implement the code to predict the class from an image file

    # Process the image
    pil_image = Image.open(image_path)
    image = process_image(pil_image)

    # Unsqueeze to add batch dimension (B, C, H, W)
    image = image.unsqueeze(0)

    # Move model and input to the appropriate device
    model.to(device)
    image = image.to(device)

    # Set the model to evaluation mode (turns off dropout)
    model.eval()

    # Forward pass to get log probabilities
    with torch.no_grad():
        logps = model.forward(image)

    # Calculate actual probabilities and get top k results
    ps = torch.exp(logps)
    top_p, top_idx = ps.topk(topk, dim=1)

    # Convert tensors to lists for easier manipulation
    top_p = top_p.cpu().numpy()[0].tolist()
    top_idx = top_idx.cpu().numpy()[0].tolist()

    # Invert the class_to_idx dictionary to map indices to classes
    idx_to_class = {val: key for key, val in model.class_to_idx.items()}

    # Map the predicted indices to their corresponding class labels
    top_class = [idx_to_class[idx] for idx in top_idx]

    return top_p, top_class

# %%
#####################
# Image & model
#####################

image_path = 'data/flowers/test/4/image_05637.jpg'
model = load_checkpoint_vgg16('checkpoints/image_classifier_checkpoint.pth').to(device)

probs, classes = predict(image_path, model)

print(probs)
print(classes)
# Out:
# [0.46379008889198303, 0.23733384907245636, 0.132488414645195, 0.047532111406326294, 0.03236796706914902]
# ['94', '4', '88', '9', '7']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# DONE: Display an image along with the top 5 classes

#####################
# Display the result
#####################

# Set up the plot layout (2 rows, 1 column)
fig, (ax1, ax2) = plt.subplots(figsize=(6, 9), nrows=2, ncols=1)

# Process and display the image
pil_image = Image.open(image_path)
image = process_image(pil_image)

# Use existing imshow function to display the image on the first subplot
imshow(image, ax=ax1)
ax1.axis('off')

# Get predictions
probs, classes = predict(image_path, model)

# Map the predicted class indices to their actual flower names
class_names = [cat_to_name[cls] for cls in classes]

# Set the title of the image to the most likely flower name
ax1.set_title(class_names[0])

# Display the bar chart on the second subplot
y_pos = np.arange(len(class_names))
ax2.barh(y_pos, probs, align='center', color='steelblue')
ax2.set_yticks(y_pos)
ax2.set_yticklabels(class_names)
ax2.invert_yaxis()  # Invert so the highest probability is at the top

# Turn off the grid for the bar chart
ax2.grid(False)
ax1.grid(False)


plt.tight_layout()
plt.show()
